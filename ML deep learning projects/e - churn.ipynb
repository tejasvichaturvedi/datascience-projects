# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\code\exercise churn\Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(['CustomerId','RowNumber','Surname','Age'],axis='columns',inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female       2       0.00              1
# 1             608     Spain  Female       1   83807.86              1
# 2             502    France  Female       8  159660.80              3
# 3             699    France  Female       1       0.00              2
# 4             850     Spain  Female       2  125510.82              1
# ...           ...       ...     ...     ...        ...            ...
# 9995          771    France    Male       5       0.00              2
# 9996          516    France    Male      10   57369.61              1
# 9997          709    France  Female       7       0.00              1
# 9998          772   Germany    Male       3   75075.31              2
# 9999          792    France  Female       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# ...

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
for column in df:
    print(f'{column}:{df[column].unique()}')
# Out:
# CreditScore:[619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
# ...

# %%
df = pd.get_dummies(data=df, columns=['Geography', 'Gender'])
df.columns
# Out:
# Index(['CreditScore', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
df
# Out:
#       CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       2       0.00              1          1
# 1             608       1   83807.86              1          0
# 2             502       8  159660.80              3          1
# 3             699       1       0.00              2          0
# 4             850       2  125510.82              1          1
# ...           ...     ...        ...            ...        ...
# 9995          771       5       0.00              2          1
# 9996          516      10   57369.61              1          1
# 9997          709       7       0.00              1          0
# 9998          772       3   75075.31              2          1
# 9999          792       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1        101348.88       1                 1
# 1                  1        112542.58       0                 0
# ...

# %%
cols_to_scale = ['Tenure','EstimatedSalary','Balance','CreditScore','NumOfProducts']
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()
df[cols_to_scale] = Scaler.fit_transform(df[cols_to_scale])

# %%
df.head()
# Out:
#    CreditScore  Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        0.538     0.2  0.000000       0.000000          1               1
# 1        0.516     0.1  0.334031       0.000000          0               1
# 2        0.304     0.8  0.636357       0.666667          1               0
# 3        0.698     0.1  0.000000       0.333333          0               0
# 4        1.000     0.2  0.500246       0.000000          1               1
#
#    EstimatedSalary  Exited  Geography_France  Geography_Germany  \
# 0         0.506735       1                 1                  0
# 1         0.562709       0                 0                  0
# 2         0.569654       1                 1                  0
# 3         0.469120       0                 1                  0
# 4         0.395400       0                 0                  0
#
#    Geography_Spain  Gender_Female  Gender_Male
# 0                0              1            0
# ...

# %%
df.columns[df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
X = df.drop('Exited',axis='columns')
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
X_test.shape
# Out:
# (2000, 12)

# %%
len(X_train.columns)
# Out:
# 12

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix, classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss):
    import tensorflow as tf
    from tensorflow import keras
    model = keras.Sequential([
         keras.layers.Dense(6,input_shape=(12,),activation='relu'),
         keras.layers.Dense(4,activation='relu'),
        keras.layers.Dense(1,activation='sigmoid')
])
    model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=100)
    print(model.evaluate(X_test, y_test))

    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)

    print("Classification Report: \n", classification_report(y_test, y_preds))

    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy')
# Out:
# Epoch 1/100
# 250/250 [==============================] - 3s 5ms/step - loss: 0.5613 - accuracy: 0.7409
# Epoch 2/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4863 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4769 - accuracy: 0.7960
# Epoch 4/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.4743 - accuracy: 0.7960
# Epoch 5/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.4730 - accuracy: 0.7960
# Epoch 6/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4724 - accuracy: 0.7960
# Epoch 7/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4718 - accuracy: 0.7960
# Epoch 8/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4708 - accuracy: 0.7960
# Epoch 9/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4708 - accuracy: 0.7962
# Epoch 10/100
# ...
